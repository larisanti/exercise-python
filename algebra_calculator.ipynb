# %% [markdown]
# # My Calculator
#
# Estou construindo uma calculadora para me ajudar a praticar matemática e lógica de programação.
# Também é parte dos meus estudos no curso College Algebra with Python (freeCodeCamp).

# %% [markdown]
# ---
# ### Proportion (Regra de Três)

# %%
def resolver_proporcao(n1, d1, n2, d2):
    """
    Resolve uma regra de três simples. 
    Valor 0 é o que desejo descobrir (incógnita).
    """
    answer_variable = ""
    
    # Se n2 for a incógnita
    if n2 == 0:
        answer = d2 * n1 / d1
        n2 = answer 
        answer_variable = "n2"

    # Se d2 for a incógnita
    elif d2 == 0:
        answer = n2 * d1 / n1
        d2 = answer
        answer_variable = "d2"
        
    # Se n1 for a incógnita
    elif n1 == 0:
        answer = d1 * n2 / d2
        n1 = answer
        answer_variable = "n1"
        
    # Se d1 for a incógnita
    elif d1 == 0:
        answer = n1 * d2 / n2
        d1 = answer
        answer_variable = "d1"

    if answer_variable:
        print(f"Resultado: {answer_variable} = {answer}")
        print(f"Proporção completa: {n1}/{d1} = {n2}/{d2}")
    else:
        print("Nenhuma incógnita (0) foi informada.")

# %%
# Resolver (icógnita = 0)
resolver_proporcao(n1=1, d1=2, n2=4, d2=0)
# Out:
# Resultado: d2 = 8.0
# Proporção completa: 1/2 = 4/8.0

# %% [markdown]
# ---
# ### Média de Homework Score
#
# Automatizei o cálculo da média do aproveitamento de homework dos meus alunos.

# %%
score_total = []
qtd_atividade = int(input("Quantidade de atividades:"))

# Loop para calcular o score de cada atividade com base nos acertos e total
for i in range(1, qtd_atividade + 1):
    entrada = input(f"Atividade {i} (acerto/total): ")
    
    a, t = map(int, entrada.split('/'))
    score_parcial = (a * 100) / t
    
    score_total.append(score_parcial)
    print(f"Atividade {i}: {score_parcial:.2f}%")

# Média simples para score total
if score_total:
    media_final = sum(score_total) / len(score_total)
    print(f"Score: {media_final:.2f}%")
# Out:
# Atividade 1: 100.00%
# Atividade 2: 88.89%
# Atividade 3: 66.67%
# Score: 85.19%

# %% [markdown]
# ---
# ### Calcular preço de PH

# %%
# Opção 1
rolos1 = 12
metros1 = 30
preco1 = 27.50

# Opção 2
rolos2 = 16
metros2 = 30
preco2 = 35.16

# Calcula o preço por metro de cada opção
preco_metro1 = preco1 / (rolos1 * metros1)
preco_metro2 = preco2 / (rolos2 * metros2)

print("Opção 1 custa por metro: R$", preco_metro1)
print("Opção 2 custa por metro: R$", preco_metro2)
# Out:
# Opção 1 custa por metro: R$ 0.0763888888888889
# Opção 2 custa por metro: R$ 0.07325

# %% [markdown]
# ---
# ### Calcular cofrinho

# %%
def calcular_cofrinho(semanas):
    dinheiro_total = 10 * semanas + 50 
    return dinheiro_total

print("Semanas \t Dinheiro guardado")

for x in range(5):
    resultado = calcular_cofrinho(x)
    print(x, "\t\t R$", resultado)
# Out:
# Semanas 	 Dinheiro guardado
# 0 		 R$ 50
# 1 		 R$ 60
# 2 		 R$ 70
# 3 		 R$ 80
# 4 		 R$ 90
